# %% [markdown]
# Esto es la práctica 1 de la asignatura VC

# %%
import numpy as np
import cv2 as cv
import matplotlib as plt
from google.colab import drive
from google.colab.patches import cv2_imshow
drive.mount('/content/drive')
# !ls '/content/drive/MyDrive'
np.random.seed(0)

# %% [markdown]
# Aquí enseñamos el ejercicio 1, cogemos la imagen y si ponemos el flag a 0 la tenemos en escala de grises pero con el flag a 1 lo tenemos en color completo

# %%
imagen1PATH = "/content/drive/MyDrive/CUADERNOS_COLAB/P0/Girl-Stock.jpeg"

#imBW = cv.imread(imagen1PATH,0)
#imRGB = cv.imread(imagen1PATH,1)
#cv2_imshow(imBW)
#cv2_imshow(imRGB)

imgs = ["/content/drive/MyDrive/CUADERNOS_COLAB/P0/Girl-Stock.jpeg"]

for img in imgs:
  image = cv.imread(img) 
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  image_3 = cv.cvtColor(image, cv.COLOR_BGR2GRAY)
  image_4 = cv.cvtColor(image_2, cv.COLOR_BGR2GRAY)
  final_frame = cv.hconcat((image, image_2))
  final_frame2 = cv.hconcat((image_3, image_4))
  cv2_imshow(final_frame)
  cv2_imshow(final_frame2)
  print('\n')

imagenRND = np.random.rand(500,500,3) * 5
cv2_imshow(imagenRND)
# Out:
# <PIL.Image.Image image mode=RGB size=960x270 at 0x7F1EBEBCFC90>
# <PIL.Image.Image image mode=L size=960x270 at 0x7F1EBEBCFE90>
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7F1EC35956D0>
